# %% [markdown]
# # Creation of datasets
#
# In this notebook, we solve the TOV equations for NS with a specific EOS composed of three regions: at low energy scales we use a known table of EOS (either SLy or AP4); for mass densities larger than twice the saturation density we implement an agnostic speed-of-sound parametrization; finally, for a pressure larger than (200 MeV)^4, we implement a vacuum energy phase transition.
#
# We also collect the data to create the inputs and outputs for the training/validation/testing process of our deep neural networks (provided in a different python notebook).
#
# Finally, we implement a section to study the EOSs predicted by the neural networks, we solve the TOV equations (and the equation for the tidal deformability) and we compare the result with the expected ones.
#
# We work in G=c=M_sun=1 units.

# %% [markdown]
# ## Import packages

# %%
using DifferentialEquations, DelimitedFiles, Interpolations, Symbolics, Printf, Plots, Roots, Random, Distributions, CSV, LaTeXStrings, Images, Statistics

# %% [markdown]
# ## Load data and units conventions

# %% [markdown]
# Let us load the data and some useful constants. We load the SLy and AP4 EOSs (appropriately rescaled); we also upload the random mass density and speed-of-sound values to create the c_s parametrization. We generate the training and validation datasets from the files "matrixrho2.dat" and "matrixcs2.dat"; the testing dataset is generated from "matrixrhoTest.dat" and "matrixcsTest.dat". Uncomment the appropriate datasets.

# %%
#LOADING DATA
sly = readdlm("Rescaledsly.dat", Float64) #p,ϵ,ρ
ap4 = readdlm("Rescaledap4.dat", Float64); #p,ϵ,ρ
#Data for generating training and validation datasets
#matrix_ρ = readdlm("matrixrho2.dat", Float64) #loading ρ coordinates for segments, 1000 eos
#matrix_cs = readdlm("matrixcs2.dat", Float64); #loading cs coordinates for segments, 1000 eos
#Data for generating testing dataset
matrix_ρ = readdlm("matrixrhoTest.dat", Float64) #loading ρ coordinates for segments, 100 eos
matrix_cs = readdlm("matrixcsTest.dat", Float64); #loading cs coordinates for segments, 100 eos

# %%
#CONSTANTS FOR UNITS
const cspeed = 2.997 * 10.0^10 #cm s^-1
const hbar = 6.582 * 10.0^-22 #Mev s
const MeV = 1.602 * 10.0^-6 #g cm^2 s^-1
const Kp = MeV/(hbar^3 * cspeed^3) #in g and cm
const Kρ = MeV/(hbar^3 * cspeed^5) #in g and cm
const fm = (10.0^-13)^-3 #fm^-3 in cm^-3
const n0 = 0.16 * fm #nuclear saturation density in cm^-3
const m = 1.675 * 10.0^-24 #neutron mass in g
const Msun = 1.988 * 10.0^33 #in g
const Gconst = 6.67 * 10.0^-11 * 10.0^6/10.0^3 #cm^3/g/s^2
const Lu = Msun^-1 * cspeed^2 * Gconst^-1 #1cm in G=c=Msun=1
const Pu = Msun^-1 / Lu^3 / cspeed^2
const ρu = Msun^-1 / Lu^3;
const KK = (2.997 * 10.0^5)^2/(6.67 * 10.0^-20 * 1.988 * 10.0^30);#rescaling for λ to check with GW

# %% [markdown]
# ## Functions definition

# %% [markdown]
# We defined the functions to create the EOS and to solve the TOV and tidal deformability equations.
#
# <u>Important note</u>: in the function "csInterp", we used an old interpolation for the first value of the speed of sound namely:
#
# "segm_matrix = vcat(segm_matrix, [eos[k,3] p1])".
#
# This choice is obsolete and is now commented. The new and correct values is given by:
#
# "segm_matrix = vcat(segm_matrix, [eos[k,3] sqrt(p1)])",
#
# marked as new implementation. The training/validation dataset had been created with the old implementation, and, to ensure that initial hypothesis were the same, we used the old implementation for the testing dataset as well.
#
# If you intend to use this code, we recommend to use the new implementation for the creation of all datasets.

# %%
# function to find (closest) position in array of certain value IT WORKS FOR INCREASING VALUE
function findpos(matrix,value,column)
    for b = 1:length(matrix[:,column])
        Δx1 = abs(matrix[b,column] - value)
        Δx2 = abs(matrix[b+1,column] - value)
        if matrix[b+1,column] >= value
            if Δx1 < Δx2
                return b
                break
            else
                return b+1
                break
            end
        end
    end
end;

# %%
#Evaluating derivative functions to find quantities at threshold
function derThr(eos, k)
    s = 0.0
    for j = 1:k
        Δp = eos[j+1,1] - eos[j,1]
        Δϵ = eos[j+1,2] - eos[j,2]
        s = Δp/Δϵ
    end
    return s
end

#creating an interpolated function for speed of sound modification
function csInterp(eos, k, p1, matr_ρ, matr_cs, ds)
    #define matrix to store (ρ,cs) for segments modification
    segm_matrix = Matrix{Float64}(undef,0,2) 
    #segm_matrix = vcat(segm_matrix, [eos[k,3] p1]) #old implementation
    segm_matrix = vcat(segm_matrix, [eos[k,3] sqrt(p1)]) #new implementation
    for j = 1:7
      segm_matrix = vcat(segm_matrix, [matr_ρ[ds,j] matr_cs[ds,j]])  
    end
    
    cs_interp = linear_interpolation(segm_matrix[:,1],segm_matrix[:,2])
end

#create high energy eos
function heEOS(he_eos::AbstractMatrix{T}, eos, k, cs_interp) where T
    Δρ = 10.0^-5
    M = div((10.0^-3 - eos[k,3]),10.0^-5)+div((10.0^-2 - 10.0^-3),10.0^-4)+
        div((ρfin - 10.0^-2),10.0^-3)    
    ρold = eos[k,3]
    ϵold = eos[k,2]
    pold = eos[k,1]
    
    for j = 1:M-1
        ρnew = ρold + Δρ
        ϵnew = ϵold + Δρ * (ϵold + pold)/ρold
        pnew = pold + cs_interp(ρold)^2 * Δρ * (ϵold + pold)/ρold #cs^2=dp/dϵ
        if ρnew > ρfin #break cycle if we reach last mass density
            break
        end
        he_eos = vcat(he_eos, [pnew ϵnew ρnew])
        ρold = ρnew #store new data in old variable for next loop
        ϵold = ϵnew
        pold = pnew
        if ρnew < 10.0^-3
            Δρ = 10.0^-5
        elseif ρnew < 10.0^-2
            Δρ = 10.0^-4
        elseif ρnew < 10^-1
            Δρ = 10.0^-3
        else 
            Δρ = 10.0^-2
        end
    end
    return he_eos
end

#merge two EOS
function mergeEOS(eos_matrix::AbstractMatrix{T}, he_eos, eos, k) where T
    N = k + length(he_eos[:,1])
    for j = 1:N
        if j <= k
            eos_matrix = vcat(eos_matrix, [eos[j,1] eos[j,2] eos[j,3]])
        else
            eos_matrix = vcat(eos_matrix, [he_eos[j-k,1] he_eos[j-k,2] he_eos[j-k,3]])
        end 
    end
    return eos_matrix
end

#BUILDING EOS before Λ transition
function build(eos_matrix::AbstractMatrix{T}, eos, matr_ρ, matr_cs, ds) where T
    #find quantities at transition threshold
    k = findpos(eos,ρt,3)
    
    #Evaluating derivative functions to find quantities at threshold
    p1 = derThr(eos, k)
    
    #creating an interpolated function for speed of sound modification
    cs_interp = csInterp(eos, k, p1, matr_ρ, matr_cs, ds)
       
    #define matrix to store new part of eos
    he_eos = Matrix{Float64}(undef,0,3)
    he_eos = heEOS(he_eos, eos, k, cs_interp)
        
    #merge the two eos at right threshold
    eos_matrix = mergeEOS(eos_matrix, he_eos, eos, k)
    return eos_matrix
end;

# %%
#define interpolated eos before and after transition
function eos_interp(x) 
    if x < pc
        ϵ_fluid(x)
    elseif x >= pc
        ϵ_fluid(x + Λ) + Λ
    end
end 
#define derivative of interpolated eos before and after transition
function eos_prime_interp(x) 
    if x < pc
        ϵ_prime(x)
    elseif x >= pc
        ϵ_prime(x + Λ)
    end
end;

# %%
function integrator(P0)
    #condition when defining surface and stop integration
    condition(u, r, integrator) =  u[3]/P0 < 10.0^-12 #10^-10
    affect!(integrator) = terminate!(integrator)
    cb = DiscreteCallback(condition, affect!)
    
    u0 = [f0, h0, P0, H0, β0]
    
    #probably must use specialization SciMLBase.FullSpecialize for cycles
    prob = ODEProblem(tov!, u0, rspan)
    
    sol = solve(prob, RK4(), callback = cb, dt = 0.0005, adaptive = false)
    return sol
end;

# %%
#Define the system of eqs to solve
function tov!(du, u, p, r) #u=f,h,P,H,β
    du[1] = (1.0 - u[1] - 8.0 * π * r^2 * eos_interp(u[3]) )/r
    du[2] = -(u[2] * (-1.0 + u[1] - 8.0 * π * r^2 * u[3]))/(r * u[1])
    du[3] = (-1.0 + u[1] - 8.0 * π * r^2 * u[3]) * (u[3] + 
        eos_interp(u[3]) ) /(2.0 * r * u[1])
    du[4] = u[5]
    du[5] = (u[4] * (-u[1]^3 + (1.0 +  8.0 * π * r^2 * u[3])^3 -
            u[1] * (1.0 + 8.0 * π * r^2 * u[3]) * (-3.0 + 60.0 * π * r^2 * u[3] + 
            20.0 * π * r^2 * eos_interp(u[3]) ) 
            + u[1]^2 * (-3.0 + 60.0 * π * r^2 * u[3] + 
            8.0 * π * r^3 * eos_prime_interp(u[3]) * (-1.0 + u[1] - #ϵ'[r]=dϵ/dp*p'=dϵ/dp*du[3]
            8.0 * π * r^2 * u[3]) * (u[3] + 
            eos_interp(u[3]) ) /(2.0 * r * u[1])+
            20.0 * π * r^2 * eos_interp(u[3]) )) + 
            r * u[1] * (-1 + u[1] - 8.0 * π * r^2 * u[3]) * (1.0 + u[1] + 
            4.0 * π * r^2 * u[3] -
            4.0 * π * r^2 * eos_interp(u[3]) ) * u[5])/(r^2 * u[1]^2 * (1.0 - 
            u[1] + 8.0 * π * r^2 * u[3]))
end;

# %%
function cycleTOV(DATA_matrix::AbstractMatrix{T}, P0, Pf) where T
    #determine how long the loop is
    if Pf > 10.0^-2
        N = floor((10.0^-4 - P0)/(2.5*10.0^-6) + (10.0^-3 - 10.0^-4)/(2.5*10.0^-5) +
        (10.0^-2 - 10.0^-3)/(2.5*10.0^-4))
    elseif Pf > 10.0^-3
        N = floor((10.0^-4 - P0)/(2.5*10.0^-6) + (10.0^-3 - 10.0^-4)/(2.5*10.0^-5) +
        (Pf - 10.0^-3)/(2.5*10.0^-4))
    elseif Pf > 10.0^-4
        N = floor((10.0^-4 - P0)/(2.5*10.0^-6) + (Pf - 10.0^-4)/(2.5*10.0^-5))
    elseif Pf > 10.0^-5
        N = floor((Pf - P0)/(2.5*10.0^-6))
    end

    for i=1:N
        sol = integrator(P0)
    
        Rs = sol.t[end] #radius
        M = Rs/2 * (1 - sol[1,end]) #mass
        y = Rs * sol[5,end]/sol[4,end]
        C = M / (Rs / Lu * 10^-5) #compactness
        #Love number k2
        k2 = (8.0 * (1.0 - 2.0 * C)^2 * C^5 * (2.0 + 2.0 * C * (-1.0 + y) -
            y))/(5.0 * (2.0 * C * (6.0 + C^2 * (26.0 - 22.0 * y) - 3.0 * y +
            4 * C^4 * (1.0 + y) + 3.0 * C * (-8.0 + 5.0 * y) + C^3 * (-4.0 + 6.0 * y)) +
            3.0 * (1.0 - 2.0 * C)^2 * (2.0 + 2.0 * C * (-1.0 + y) - y) * log(1 - 2*C)))
        λ = 2.0/3.0 * k2 * (Rs / Lu * 10^-5)^5 * KK^5/(M)^5 #tidal deformability resc
                
        #store values in matrix, create a new row each M-R loop
        DATA_matrix = vcat(DATA_matrix, [P0/ρu M Rs/Lu*10.0^-5 λ])
    
        #increment on P0
        if P0 < 10.0^-4       
            P0 = P0 + 2.5*10.0^-6
        elseif P0 < 10.0^-3
            P0 = P0 + 2.5*10.0^-5
        elseif P0 < 10.0^-2
            P0 = P0 + 2.5*10.0^-4
        else 
            P0 = P0 + 2.5*10.0^-3
        end
    end
    return DATA_matrix
end;

# %% [markdown]
# ## Equations Integration

# %% [markdown]
# We integrate here the TOV and tidal deformability equations for all possible EOSs' combinations.
#
# We save the results only for those EOSs that have a maximum mass compatible with PSR J0952-0607 which has a M_max=2.35+-0.17.
#
# The results for the training and validation datasets are saved in the folder "TOVs", those for the testing dataset are saved in "TOVsTest".
#
# Note: choose baseline EOS (AP4 or SLy).

# %%
const ρt = 2.0 * n0 * m * ρu #mass density when first transition happens
const ρfin = 12.0 * n0 * m * ρu
const pc = 200.0^4 * Kp * Pu #threshold for vacuum energy trans. corresponds to qcd scale
#define initial values for solving integration as global
const r0 = 10^-5
const a0 = 1.0
const f0 = 1.0
const h0 = 1.0
const H0 = a0 * r0^2
const β0 = 2. * a0 * r0
const rspan = (r0, 200)
#All possible values of Λ considered
Λarray = [-194.0^4 * Kp * Pu, -150.0^4 * Kp * Pu, -120.0^4 * Kp * Pu, -95.0^4 * Kp * Pu,
    -50.0^4 * Kp * Pu, 0., 50.0^4 * Kp * Pu, 95.0^4 * Kp * Pu, 120.0^4 * Kp * Pu,
    194.0^4 * Kp * Pu];

# %%
Λ = 0.
ϵ_fluid = zeros(0)
ϵ_prime(x::Any) = zeros(0)
#DATA_matrix = Matrix{Float64}(undef,0,4) 

for q = 1:length(Λarray)
    Λ = Λarray[q]
    @show Λ
    for j = 1:length(matrix_ρ[:,1])
        z = j
        @show j
    
        eos_matrix = Matrix{Float64}(undef,0,3) #define matrix to store complete eos
        eos_matrix = build(eos_matrix, sly, matrix_ρ, matrix_cs, z)
        
        #ϵ[p] before transition
        ϵ_fluid = linear_interpolation(eos_matrix[:,1],eos_matrix[:,2])
        #define interpolated dϵ[p]/dp
        ϵ_prime(x) = only(Interpolations.gradient(ϵ_fluid, x) );
        
        #INTEGRATOR
        P0 = 2.5 * 10^-5  #this will vary at each step of loop
        Pf = 0. #define it
        #Find what Pf is
        if Λ > 0 && eos_matrix[end,1] > pc
            Pf = eos_matrix[end,1] - Λ
        else
            Pf = eos_matrix[end,1]
        end
    
        #create empty matrix to store data in loop
        DATA_matrix = Matrix{Float64}(undef,0,4) 

        @time DATA_matrix = cycleTOV(DATA_matrix, P0, Pf)

        Mmax, iMax = findmax(DATA_matrix[:,2])
        
        if Λ == 0.0
            temp = 0
        else
            temp = floor(Int,abs(Λ/(Kp * Pu))^(1/4)/sign(Λ))
        end
        
        #Store TOV integration
        if 2.18 < Mmax < 2.52
            #store for training and validation dataset
            #dumping = open("TOVs/TOV_ap4_"*"$temp"*"_$z.csv", "a")
            #store for testing dataset
            dumping = open("TOVsTest/TOV_sly_"*"$temp"*"_$z.csv", "a")
            writedlm(dumping, DATA_matrix, ' ')
            close(dumping)         
        end
    end
end;
# Out:
# Λ = -0.0005326622105352159
# j = 1
#   5.145330 seconds (286.28 M allocations: 5.171 GiB, 8.19% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 2
#   5.416291 seconds (303.80 M allocations: 5.467 GiB, 8.26% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 3
#   5.475339 seconds (306.85 M allocations: 5.551 GiB, 7.84% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 4
#   5.098067 seconds (283.40 M allocations: 5.152 GiB, 8.14% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 5
#   5.961533 seconds (317.48 M allocations: 5.719 GiB, 8.19% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 6
#   3.729454 seconds (201.73 M allocations: 3.678 GiB, 8.49% gc time, 1.23% compilation time: 100% of which was recompilation)
# j = 7
#   5.153940 seconds (277.91 M allocations: 5.021 GiB, 8.53% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 8
#   6.387478 seconds (337.03 M allocations: 6.064 GiB, 8.24% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 9
#   6.908019 seconds (310.19 M allocations: 5.595 GiB, 7.40% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 10
#   4.371122 seconds (206.97 M allocations: 3.771 GiB, 7.67% gc time, 1.29% compilation time: 100% of which was recompilation)
# j = 11
#   3.834770 seconds (187.25 M allocations: 3.411 GiB, 7.80% gc time, 1.42% compilation time: 100% of which was recompilation)
# j = 12
#   7.776988 seconds (354.17 M allocations: 6.345 GiB, 7.56% gc time, 0.66% compilation time: 100% of which was recompilation)
# j = 13
#   5.386640 seconds (263.40 M allocations: 4.844 GiB, 7.33% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 14
#   6.127433 seconds (320.98 M allocations: 5.766 GiB, 7.26% gc time, 0.73% compilation time: 100% of which was recompilation)
# j = 15
#   4.539921 seconds (240.95 M allocations: 4.417 GiB, 7.33% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 16
#   4.002219 seconds (212.68 M allocations: 3.879 GiB, 7.58% gc time, 1.12% compilation time: 100% of which was recompilation)
# j = 17
#   5.127194 seconds (251.64 M allocations: 4.604 GiB, 7.41% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 18
#   6.082195 seconds (290.09 M allocations: 5.258 GiB, 7.33% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 19
#   7.148298 seconds (284.96 M allocations: 5.159 GiB, 6.56% gc time, 1.09% compilation time: 100% of which was recompilation)
# j = 20
#   5.477104 seconds (273.83 M allocations: 4.956 GiB, 7.33% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 21
#   5.368822 seconds (279.92 M allocations: 5.097 GiB, 7.41% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 22
#   4.604230 seconds (248.68 M allocations: 4.548 GiB, 6.94% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 23
#   5.417667 seconds (295.16 M allocations: 5.348 GiB, 7.36% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 24
#   5.230066 seconds (279.64 M allocations: 5.049 GiB, 7.49% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 25
#   5.090505 seconds (268.04 M allocations: 4.900 GiB, 7.19% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 26
#   4.987863 seconds (261.17 M allocations: 4.755 GiB, 7.73% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 27
#   4.764270 seconds (270.77 M allocations: 4.916 GiB, 7.24% gc time, 1.02% compilation time: 100% of which was recompilation)
# j = 28
#   5.857018 seconds (295.90 M allocations: 5.333 GiB, 7.45% gc time, 0.69% compilation time: 100% of which was recompilation)
# j = 29
#   6.243373 seconds (332.00 M allocations: 5.984 GiB, 7.41% gc time, 0.71% compilation time: 100% of which was recompilation)
# j = 30
#   5.428544 seconds (251.76 M allocations: 4.615 GiB, 7.14% gc time, 0.96% compilation time: 100% of which was recompilation)
# j = 31
#   5.603719 seconds (265.66 M allocations: 4.844 GiB, 7.35% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 32
#   6.327385 seconds (269.09 M allocations: 4.907 GiB, 6.76% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 33
#   5.551741 seconds (273.55 M allocations: 4.961 GiB, 7.54% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 34
#   6.281819 seconds (312.66 M allocations: 5.625 GiB, 7.35% gc time, 0.70% compilation time: 100% of which was recompilation)
# j = 35
#   5.178342 seconds (279.95 M allocations: 5.080 GiB, 7.16% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 36
#   5.620532 seconds (309.04 M allocations: 5.594 GiB, 7.66% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 37
#   5.196722 seconds (274.29 M allocations: 4.964 GiB, 7.31% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 38
#   3.909635 seconds (208.98 M allocations: 3.803 GiB, 7.51% gc time, 1.09% compilation time: 100% of which was recompilation)
# j = 39
#   5.403095 seconds (290.21 M allocations: 5.278 GiB, 7.45% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 40
#   6.081461 seconds (318.91 M allocations: 5.733 GiB, 7.63% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 41
#   6.410309 seconds (332.69 M allocations: 5.969 GiB, 7.53% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 42
#   5.084536 seconds (287.31 M allocations: 5.197 GiB, 7.68% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 43
#   4.995558 seconds (283.80 M allocations: 5.132 GiB, 7.67% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 44
#   5.339392 seconds (300.47 M allocations: 5.397 GiB, 7.53% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 45
#   6.457528 seconds (363.94 M allocations: 6.491 GiB, 7.60% gc time, 0.65% compilation time: 100% of which was recompilation)
# j = 46
#   5.742364 seconds (299.85 M allocations: 5.396 GiB, 7.65% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 47
#   5.423731 seconds (281.18 M allocations: 5.108 GiB, 7.28% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 48
#   5.261981 seconds (281.93 M allocations: 5.120 GiB, 7.46% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 49
#   5.116196 seconds (267.17 M allocations: 4.851 GiB, 7.61% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 50
#   5.268071 seconds (284.94 M allocations: 5.168 GiB, 7.60% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 51
#   7.298917 seconds (398.20 M allocations: 7.087 GiB, 7.81% gc time, 0.61% compilation time: 100% of which was recompilation)
# j = 52
#   5.559009 seconds (298.06 M allocations: 5.393 GiB, 7.75% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 53
#   5.292178 seconds (294.40 M allocations: 5.309 GiB, 7.51% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 54
#   5.606644 seconds (302.54 M allocations: 5.439 GiB, 7.74% gc time, 0.73% compilation time: 100% of which was recompilation)
# j = 55
#   6.404752 seconds (309.57 M allocations: 5.559 GiB, 7.75% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 56
#   5.832397 seconds (288.02 M allocations: 5.217 GiB, 7.61% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 57
#   5.334394 seconds (278.31 M allocations: 5.027 GiB, 7.62% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 58
#   5.893555 seconds (311.56 M allocations: 5.625 GiB, 7.66% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 59
#   5.415533 seconds (282.92 M allocations: 5.118 GiB, 7.41% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 60
#   6.041453 seconds (314.09 M allocations: 5.648 GiB, 7.78% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 61
#   4.871968 seconds (259.05 M allocations: 4.731 GiB, 7.74% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 62
#   5.136939 seconds (260.87 M allocations: 4.750 GiB, 7.54% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 63
#   5.688174 seconds (291.10 M allocations: 5.257 GiB, 7.65% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 64
#   5.114743 seconds (269.07 M allocations: 4.898 GiB, 7.58% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 65
#   3.502642 seconds (182.57 M allocations: 3.319 GiB, 7.60% gc time, 1.26% compilation time: 100% of which was recompilation)
# j = 66
#   5.083711 seconds (273.02 M allocations: 4.961 GiB, 7.51% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 67
#   4.559778 seconds (247.95 M allocations: 4.546 GiB, 7.38% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 68
#   4.738917 seconds (266.14 M allocations: 4.843 GiB, 7.41% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 69
#   5.102556 seconds (285.26 M allocations: 5.147 GiB, 7.77% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 70
#   4.901397 seconds (275.48 M allocations: 4.991 GiB, 7.79% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 71
#   5.471610 seconds (307.10 M allocations: 5.554 GiB, 7.62% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 72
#   4.853882 seconds (273.06 M allocations: 4.988 GiB, 7.67% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 73
#   5.760677 seconds (321.39 M allocations: 5.772 GiB, 7.86% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 74
#   5.200199 seconds (290.21 M allocations: 5.269 GiB, 7.68% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 75
#   5.182545 seconds (286.60 M allocations: 5.220 GiB, 7.67% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 76
#   5.575871 seconds (307.35 M allocations: 5.541 GiB, 7.70% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 77
#   5.249524 seconds (292.91 M allocations: 5.286 GiB, 7.66% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 78
#   4.743844 seconds (263.58 M allocations: 4.793 GiB, 7.49% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 79
#   4.967170 seconds (276.09 M allocations: 5.010 GiB, 7.68% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 80
#   5.949723 seconds (325.28 M allocations: 5.852 GiB, 7.69% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 81
#   5.461728 seconds (302.50 M allocations: 5.455 GiB, 7.67% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 82
#   5.158915 seconds (286.50 M allocations: 5.210 GiB, 7.51% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 83
#   4.218155 seconds (235.72 M allocations: 4.307 GiB, 7.62% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 84
#   5.098894 seconds (286.92 M allocations: 5.208 GiB, 7.66% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 85
#   5.736801 seconds (316.08 M allocations: 5.662 GiB, 7.87% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 86
#   4.987334 seconds (277.97 M allocations: 5.048 GiB, 7.66% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 87
#   4.283432 seconds (231.57 M allocations: 4.215 GiB, 7.83% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 88
#   5.183487 seconds (290.27 M allocations: 5.270 GiB, 7.63% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 89
#   5.376779 seconds (300.13 M allocations: 5.461 GiB, 7.55% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 90
#   5.185100 seconds (282.18 M allocations: 5.106 GiB, 7.58% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 91
#   4.535697 seconds (253.70 M allocations: 4.646 GiB, 7.68% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 92
#   4.720433 seconds (263.15 M allocations: 4.795 GiB, 7.68% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 93
#   5.118463 seconds (281.34 M allocations: 5.093 GiB, 7.57% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 94
#   5.919341 seconds (325.29 M allocations: 5.843 GiB, 7.93% gc time, 0.71% compilation time: 100% of which was recompilation)
# j = 95
#   5.178490 seconds (287.89 M allocations: 5.241 GiB, 7.54% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 96
#   4.497071 seconds (249.56 M allocations: 4.571 GiB, 7.50% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 97
#   4.995296 seconds (278.47 M allocations: 5.039 GiB, 7.61% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 98
#   5.274926 seconds (291.67 M allocations: 5.275 GiB, 7.63% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 99
#   6.485549 seconds (357.70 M allocations: 6.427 GiB, 7.80% gc time, 0.64% compilation time: 100% of which was recompilation)
# j = 100
#   6.226333 seconds (348.28 M allocations: 6.260 GiB, 7.62% gc time, 0.67% compilation time: 100% of which was recompilation)
# Λ = -0.00019037503823413876
# j = 1
#   4.950325 seconds (277.20 M allocations: 5.031 GiB, 7.62% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 2
#   5.257976 seconds (294.21 M allocations: 5.317 GiB, 7.68% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 3
#   5.280301 seconds (295.56 M allocations: 5.374 GiB, 7.54% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 4
#   5.315505 seconds (275.17 M allocations: 5.024 GiB, 7.76% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 5
#   6.333447 seconds (305.06 M allocations: 5.525 GiB, 7.82% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 6
#   4.123611 seconds (201.73 M allocations: 3.678 GiB, 7.91% gc time, 1.22% compilation time: 100% of which was recompilation)
# j = 7
#   5.636689 seconds (270.71 M allocations: 4.909 GiB, 8.16% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 8
#   6.682670 seconds (322.01 M allocations: 5.829 GiB, 7.85% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 9
#   5.972694 seconds (297.46 M allocations: 5.396 GiB, 7.74% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 10
#   4.081292 seconds (207.08 M allocations: 3.773 GiB, 8.04% gc time, 1.11% compilation time: 100% of which was recompilation)
# j = 11
#   3.717414 seconds (187.25 M allocations: 3.411 GiB, 7.80% gc time, 1.25% compilation time: 100% of which was recompilation)
# j = 12
#   6.755632 seconds (337.73 M allocations: 6.087 GiB, 8.49% gc time, 0.66% compilation time: 100% of which was recompilation)
# j = 13
#   5.167679 seconds (259.81 M allocations: 4.788 GiB, 7.77% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 14
#   6.140792 seconds (307.80 M allocations: 5.560 GiB, 7.80% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 15
#   4.753923 seconds (238.97 M allocations: 4.387 GiB, 7.77% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 16
#   4.262271 seconds (212.88 M allocations: 3.883 GiB, 7.99% gc time, 1.12% compilation time: 100% of which was recompilation)
# j = 17
#   5.038452 seconds (248.22 M allocations: 4.552 GiB, 8.13% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 18
#   5.919858 seconds (280.77 M allocations: 5.113 GiB, 7.73% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 19
#   5.681079 seconds (276.28 M allocations: 5.024 GiB, 8.01% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 20
#   5.613279 seconds (266.48 M allocations: 4.843 GiB, 7.66% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 21
#   5.452222 seconds (272.43 M allocations: 4.981 GiB, 7.35% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 22
#   4.928253 seconds (245.49 M allocations: 4.499 GiB, 7.93% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 23
#   5.684413 seconds (285.27 M allocations: 5.193 GiB, 7.88% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 24
#   5.606196 seconds (271.66 M allocations: 4.925 GiB, 7.99% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 25
#   5.218760 seconds (262.85 M allocations: 4.820 GiB, 7.11% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 26
#   4.692223 seconds (255.91 M allocations: 4.674 GiB, 7.62% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 27
#   5.241760 seconds (264.14 M allocations: 4.814 GiB, 7.87% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 28
#   5.661257 seconds (287.10 M allocations: 5.196 GiB, 7.65% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 29
#   6.449824 seconds (317.54 M allocations: 5.758 GiB, 7.77% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 30
#   5.242204 seconds (248.73 M allocations: 4.569 GiB, 7.58% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 31
#   5.153834 seconds (260.12 M allocations: 4.759 GiB, 7.62% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 32
#   5.188892 seconds (263.18 M allocations: 4.816 GiB, 7.79% gc time, 0.96% compilation time: 100% of which was recompilation)
# j = 33
#   5.249802 seconds (266.51 M allocations: 4.851 GiB, 7.68% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 34
#   5.480303 seconds (301.47 M allocations: 5.450 GiB, 7.39% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 35
#   4.968933 seconds (272.06 M allocations: 4.957 GiB, 7.43% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 36
#   5.527939 seconds (297.83 M allocations: 5.419 GiB, 7.61% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 37
#   4.713408 seconds (267.17 M allocations: 4.854 GiB, 7.55% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 38
#   3.681006 seconds (208.88 M allocations: 3.801 GiB, 7.47% gc time, 1.12% compilation time: 100% of which was recompilation)
# j = 39
#   4.930556 seconds (281.31 M allocations: 5.139 GiB, 7.46% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 40
#   5.379313 seconds (306.50 M allocations: 5.539 GiB, 7.51% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 41
#   5.686607 seconds (317.19 M allocations: 5.727 GiB, 7.66% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 42
#   4.948301 seconds (278.94 M allocations: 5.066 GiB, 7.42% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 43
#   4.787991 seconds (275.69 M allocations: 5.006 GiB, 7.61% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 44
#   5.181591 seconds (291.16 M allocations: 5.252 GiB, 7.63% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 45
#   6.551370 seconds (344.82 M allocations: 6.192 GiB, 7.61% gc time, 0.65% compilation time: 100% of which was recompilation)
# j = 46
#   7.150184 seconds (290.56 M allocations: 5.251 GiB, 7.70% gc time, 0.58% compilation time: 100% of which was recompilation)
# j = 47
#   5.735608 seconds (273.78 M allocations: 4.993 GiB, 7.14% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 48
#   5.729380 seconds (274.18 M allocations: 4.999 GiB, 7.48% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 49
#   4.628644 seconds (261.22 M allocations: 4.758 GiB, 7.62% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 50
#   4.810561 seconds (276.08 M allocations: 5.030 GiB, 7.64% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 51
#   6.805467 seconds (375.22 M allocations: 6.726 GiB, 7.78% gc time, 0.61% compilation time: 100% of which was recompilation)
# j = 52
#   5.171446 seconds (287.91 M allocations: 5.235 GiB, 7.90% gc time, 1.11% compilation time: 100% of which was recompilation)
# j = 53
#   5.072014 seconds (284.39 M allocations: 5.154 GiB, 7.52% gc time, 1.55% compilation time: 100% of which was recompilation)
# j = 54
#   5.321236 seconds (292.82 M allocations: 5.287 GiB, 7.79% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 55
#   5.464492 seconds (297.83 M allocations: 5.376 GiB, 7.63% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 56
#   5.118102 seconds (279.89 M allocations: 5.090 GiB, 7.70% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 57
#   4.986821 seconds (270.72 M allocations: 4.911 GiB, 7.59% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 58
#   5.627032 seconds (299.30 M allocations: 5.434 GiB, 7.55% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 59
#   5.322923 seconds (274.41 M allocations: 4.986 GiB, 7.66% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 60
#   5.624262 seconds (302.30 M allocations: 5.464 GiB, 7.75% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 61
#   5.403217 seconds (254.63 M allocations: 4.663 GiB, 7.78% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 62
#   4.827045 seconds (255.63 M allocations: 4.670 GiB, 7.65% gc time, 1.04% compilation time: 100% of which was recompilation)
# j = 63
#   4.996202 seconds (281.89 M allocations: 5.114 GiB, 7.73% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 64
#   4.674080 seconds (263.21 M allocations: 4.807 GiB, 7.64% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 65
#   3.240643 seconds (182.57 M allocations: 3.319 GiB, 7.81% gc time, 1.27% compilation time: 100% of which was recompilation)
# j = 66
#   4.744918 seconds (266.36 M allocations: 4.858 GiB, 7.71% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 67
#   4.385577 seconds (246.12 M allocations: 4.519 GiB, 7.71% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 68
#   4.727288 seconds (260.28 M allocations: 4.752 GiB, 7.69% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 69
#   5.924848 seconds (276.17 M allocations: 5.006 GiB, 8.18% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 70
#   5.462587 seconds (268.41 M allocations: 4.881 GiB, 7.77% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 71
#   6.114750 seconds (296.24 M allocations: 5.385 GiB, 7.88% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 72
#   5.280134 seconds (267.14 M allocations: 4.897 GiB, 7.75% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 73
#   6.140699 seconds (309.57 M allocations: 5.588 GiB, 8.04% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 74
#   5.650764 seconds (281.06 M allocations: 5.127 GiB, 7.66% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 75
#   5.675412 seconds (278.49 M allocations: 5.094 GiB, 8.20% gc time, 1.06% compilation time: 100% of which was recompilation)
# j = 76
#   5.848889 seconds (296.01 M allocations: 5.364 GiB, 7.91% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 77
#   5.670627 seconds (284.14 M allocations: 5.149 GiB, 8.26% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 78
#   5.136129 seconds (257.90 M allocations: 4.706 GiB, 7.76% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 79
#   5.329428 seconds (268.96 M allocations: 4.900 GiB, 8.01% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 80
#   6.467336 seconds (312.32 M allocations: 5.649 GiB, 7.87% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 81
#   5.818823 seconds (292.34 M allocations: 5.297 GiB, 8.15% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 82
#   5.522743 seconds (278.21 M allocations: 5.081 GiB, 7.90% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 83
#   4.705802 seconds (233.38 M allocations: 4.271 GiB, 7.61% gc time, 1.03% compilation time: 100% of which was recompilation)
# j = 84
#   5.564264 seconds (278.61 M allocations: 5.079 GiB, 8.13% gc time, 1.02% compilation time: 100% of which was recompilation)
# j = 85
#   6.075536 seconds (305.38 M allocations: 5.495 GiB, 8.12% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 86
#   5.423922 seconds (271.16 M allocations: 4.942 GiB, 8.07% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 87
#   4.738193 seconds (229.53 M allocations: 4.183 GiB, 7.84% gc time, 1.02% compilation time: 100% of which was recompilation)
# j = 88
#   5.657216 seconds (283.49 M allocations: 5.164 GiB, 8.11% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 89
#   5.857245 seconds (290.54 M allocations: 5.312 GiB, 7.92% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 90
#   5.499819 seconds (274.11 M allocations: 4.981 GiB, 7.85% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 91
#   5.032374 seconds (250.26 M allocations: 4.592 GiB, 7.65% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 92
#   5.128855 seconds (257.59 M allocations: 4.709 GiB, 8.11% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 93
#   5.500052 seconds (273.47 M allocations: 4.971 GiB, 8.12% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 94
#   6.219682 seconds (311.53 M allocations: 5.628 GiB, 7.90% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 95
#   5.581035 seconds (279.79 M allocations: 5.115 GiB, 7.83% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 96
#   4.918275 seconds (246.82 M allocations: 4.529 GiB, 7.97% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 97
#   5.333254 seconds (270.63 M allocations: 4.917 GiB, 7.78% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 98
#   5.588291 seconds (283.51 M allocations: 5.147 GiB, 7.95% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 99
#   6.819324 seconds (340.07 M allocations: 6.150 GiB, 8.00% gc time, 0.71% compilation time: 100% of which was recompilation)
# j = 100
#   6.637167 seconds (331.72 M allocations: 6.001 GiB, 7.90% gc time, 0.74% compilation time: 100% of which was recompilation)
# Λ = -7.797761566070325e-5
# j = 1
#   5.579119 seconds (276.51 M allocations: 5.021 GiB, 7.73% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 2
#   5.771033 seconds (292.94 M allocations: 5.298 GiB, 7.92% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 3
#   5.940797 seconds (294.42 M allocations: 5.357 GiB, 7.97% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 4
#   5.459237 seconds (274.83 M allocations: 5.019 GiB, 7.85% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 5
#   6.021490 seconds (303.48 M allocations: 5.500 GiB, 8.18% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 6
#   4.086208 seconds (201.73 M allocations: 3.678 GiB, 8.16% gc time, 1.21% compilation time: 100% of which was recompilation)
# j = 7
#   5.415764 seconds (269.81 M allocations: 4.896 GiB, 8.07% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 8
#   6.413286 seconds (320.04 M allocations: 5.798 GiB, 7.71% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 9
#   5.898513 seconds (296.50 M allocations: 5.382 GiB, 8.20% gc time, 1.05% compilation time: 100% of which was recompilation)
# j = 10
#   4.143278 seconds (207.08 M allocations: 3.773 GiB, 8.18% gc time, 1.18% compilation time: 100% of which was recompilation)
# j = 11
#   3.697407 seconds (187.25 M allocations: 3.411 GiB, 8.06% gc time, 1.34% compilation time: 100% of which was recompilation)
# j = 12
#   6.607620 seconds (335.11 M allocations: 6.046 GiB, 7.83% gc time, 0.71% compilation time: 100% of which was recompilation)
# j = 13
#   5.130362 seconds (259.52 M allocations: 4.784 GiB, 7.61% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 14
#   6.046453 seconds (305.78 M allocations: 5.529 GiB, 8.03% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 15
#   4.710130 seconds (239.00 M allocations: 4.387 GiB, 7.81% gc time, 1.05% compilation time: 100% of which was recompilation)
# j = 16
#   4.150569 seconds (212.90 M allocations: 3.883 GiB, 8.31% gc time, 1.24% compilation time: 100% of which was recompilation)
# j = 17
#   4.939169 seconds (248.22 M allocations: 4.552 GiB, 7.86% gc time, 0.96% compilation time: 100% of which was recompilation)
# j = 18
#   5.542059 seconds (280.19 M allocations: 5.104 GiB, 8.00% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 19
#   5.483787 seconds (275.67 M allocations: 5.015 GiB, 8.07% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 20
#   5.237053 seconds (266.48 M allocations: 4.843 GiB, 7.91% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 21
#   5.393067 seconds (272.10 M allocations: 4.976 GiB, 7.90% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 22
#   4.839138 seconds (245.49 M allocations: 4.500 GiB, 8.37% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 23
#   5.537287 seconds (284.61 M allocations: 5.183 GiB, 8.38% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 24
#   5.352773 seconds (271.18 M allocations: 4.918 GiB, 8.03% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 25
#   5.256098 seconds (262.66 M allocations: 4.817 GiB, 8.01% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 26
#   5.062889 seconds (255.70 M allocations: 4.671 GiB, 7.95% gc time, 0.99% compilation time: 100% of which was recompilation)
# j = 27
#   5.363147 seconds (264.06 M allocations: 4.813 GiB, 7.92% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 28
#   5.800984 seconds (286.02 M allocations: 5.179 GiB, 7.93% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 29
#   6.359099 seconds (315.86 M allocations: 5.732 GiB, 8.12% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 30
#   5.468857 seconds (248.79 M allocations: 4.570 GiB, 7.61% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 31
#   5.424360 seconds (259.87 M allocations: 4.755 GiB, 7.38% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 32
#   5.083489 seconds (263.10 M allocations: 4.815 GiB, 7.14% gc time, 1.58% compilation time: 100% of which was recompilation)
# j = 33
#   4.885431 seconds (265.87 M allocations: 4.842 GiB, 7.75% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 34
#   5.924247 seconds (299.83 M allocations: 5.425 GiB, 7.62% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 35
#   5.014186 seconds (271.66 M allocations: 4.951 GiB, 7.51% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 36
#   5.634340 seconds (296.51 M allocations: 5.398 GiB, 7.65% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 37
#   5.384649 seconds (266.73 M allocations: 4.848 GiB, 7.79% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 38
#   3.841100 seconds (208.87 M allocations: 3.801 GiB, 7.73% gc time, 1.10% compilation time: 100% of which was recompilation)
# j = 39
#   5.268058 seconds (280.69 M allocations: 5.130 GiB, 7.65% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 40
#   6.206295 seconds (304.92 M allocations: 5.515 GiB, 8.06% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 41
#   6.392743 seconds (314.93 M allocations: 5.692 GiB, 7.91% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 42
#   5.525917 seconds (277.99 M allocations: 5.052 GiB, 7.84% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 43
#   6.216473 seconds (274.93 M allocations: 4.994 GiB, 7.61% gc time, 0.73% compilation time: 100% of which was recompilation)
# j = 44
#   5.221245 seconds (289.90 M allocations: 5.232 GiB, 7.55% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 45
#   6.752305 seconds (341.81 M allocations: 6.145 GiB, 7.93% gc time, 0.63% compilation time: 100% of which was recompilation)
# j = 46
#   5.776049 seconds (289.31 M allocations: 5.232 GiB, 7.88% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 47
#   5.423767 seconds (272.73 M allocations: 4.976 GiB, 7.86% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 48
#   5.405281 seconds (273.55 M allocations: 4.990 GiB, 8.14% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 49
#   5.225212 seconds (260.58 M allocations: 4.749 GiB, 7.95% gc time, 0.96% compilation time: 100% of which was recompilation)
# j = 50
#   5.513727 seconds (275.78 M allocations: 5.026 GiB, 7.77% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 51
#   7.349633 seconds (371.15 M allocations: 6.662 GiB, 7.93% gc time, 0.68% compilation time: 100% of which was recompilation)
# j = 52
#   5.741329 seconds (287.11 M allocations: 5.223 GiB, 7.85% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 53
#   5.684229 seconds (283.10 M allocations: 5.134 GiB, 8.02% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 54
#   6.021377 seconds (291.03 M allocations: 5.260 GiB, 7.80% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 55
#   6.066092 seconds (296.74 M allocations: 5.359 GiB, 8.11% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 56
#   5.669549 seconds (278.96 M allocations: 5.075 GiB, 7.84% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 57
#   5.407045 seconds (270.85 M allocations: 4.913 GiB, 7.82% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 58
#   5.983328 seconds (298.02 M allocations: 5.414 GiB, 7.98% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 59
#   5.640796 seconds (273.71 M allocations: 4.976 GiB, 8.05% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 60
#   5.995755 seconds (300.91 M allocations: 5.442 GiB, 8.05% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 61
#   5.052734 seconds (254.60 M allocations: 4.662 GiB, 8.01% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 62
#   5.063032 seconds (255.52 M allocations: 4.668 GiB, 7.76% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 63
#   5.662243 seconds (280.69 M allocations: 5.095 GiB, 8.02% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 64
#   5.303435 seconds (262.83 M allocations: 4.802 GiB, 7.88% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 65
#   3.657428 seconds (182.57 M allocations: 3.319 GiB, 7.82% gc time, 1.28% compilation time: 100% of which was recompilation)
# j = 66
#   5.307684 seconds (266.32 M allocations: 4.858 GiB, 8.02% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 67
#   4.994292 seconds (246.22 M allocations: 4.520 GiB, 8.03% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 68
#   5.273974 seconds (260.02 M allocations: 4.748 GiB, 7.79% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 69
#   5.616950 seconds (276.11 M allocations: 5.006 GiB, 8.05% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 70
#   5.359224 seconds (267.85 M allocations: 4.873 GiB, 7.99% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 71
#   5.918092 seconds (295.15 M allocations: 5.368 GiB, 8.10% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 72
#   6.472624 seconds (267.05 M allocations: 4.896 GiB, 23.30% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 73
#   6.527075 seconds (307.87 M allocations: 5.561 GiB, 6.53% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 74
#   6.141123 seconds (280.51 M allocations: 5.118 GiB, 6.44% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 75
#   5.805057 seconds (277.65 M allocations: 5.081 GiB, 6.70% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 76
#   6.106490 seconds (294.57 M allocations: 5.342 GiB, 6.56% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 77
#   5.541160 seconds (283.19 M allocations: 5.134 GiB, 6.49% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 78
#   4.965714 seconds (257.86 M allocations: 4.705 GiB, 6.60% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 79
#   5.098055 seconds (269.02 M allocations: 4.902 GiB, 6.48% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 80
#   6.113221 seconds (310.61 M allocations: 5.622 GiB, 6.71% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 81
#   5.553023 seconds (291.21 M allocations: 5.279 GiB, 6.60% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 82
#   5.311582 seconds (277.93 M allocations: 5.077 GiB, 6.47% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 83
#   4.821204 seconds (233.31 M allocations: 4.270 GiB, 6.79% gc time, 1.19% compilation time: 100% of which was recompilation)
# j = 84
#   5.977696 seconds (277.99 M allocations: 5.069 GiB, 6.81% gc time, 0.73% compilation time: 100% of which was recompilation)
# j = 85
#   6.423927 seconds (303.74 M allocations: 5.470 GiB, 6.93% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 86
#   5.596883 seconds (270.38 M allocations: 4.930 GiB, 6.72% gc time, 0.90% compilation time: 100% of which was recompilation)
# j = 87
#   4.815440 seconds (229.46 M allocations: 4.183 GiB, 6.75% gc time, 1.05% compilation time: 100% of which was recompilation)
# j = 88
#   6.038370 seconds (282.31 M allocations: 5.145 GiB, 6.64% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 89
#   5.997773 seconds (289.74 M allocations: 5.299 GiB, 6.69% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 90
#   5.536355 seconds (273.40 M allocations: 4.970 GiB, 6.73% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 91
#   5.081929 seconds (249.93 M allocations: 4.587 GiB, 6.62% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 92
#   5.427044 seconds (257.35 M allocations: 4.706 GiB, 6.79% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 93
#   5.572616 seconds (272.86 M allocations: 4.961 GiB, 6.67% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 94
#   6.440089 seconds (309.16 M allocations: 5.592 GiB, 6.81% gc time, 1.10% compilation time: 100% of which was recompilation)
# j = 95
#   5.792664 seconds (279.15 M allocations: 5.105 GiB, 6.56% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 96
#   5.340131 seconds (246.39 M allocations: 4.522 GiB, 6.65% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 97
#   5.627174 seconds (270.10 M allocations: 4.909 GiB, 6.62% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 98
#   5.785379 seconds (282.40 M allocations: 5.130 GiB, 6.59% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 99
#   6.983466 seconds (337.59 M allocations: 6.112 GiB, 6.68% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 100
#   6.722396 seconds (329.35 M allocations: 5.964 GiB, 6.78% gc time, 0.77% compilation time: 100% of which was recompilation)
# Λ = -3.062946340458173e-5
# j = 1
#   5.736322 seconds (276.38 M allocations: 5.019 GiB, 6.54% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 2
#   6.047459 seconds (292.51 M allocations: 5.291 GiB, 6.79% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 3
#   6.141462 seconds (294.04 M allocations: 5.351 GiB, 6.55% gc time, 0.79% compilation time: 100% of which was recompilation)
# j = 4
#   5.799544 seconds (274.73 M allocations: 5.018 GiB, 6.64% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 5
#   6.262457 seconds (302.93 M allocations: 5.492 GiB, 6.72% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 6
#   4.286430 seconds (201.73 M allocations: 3.678 GiB, 6.91% gc time, 1.10% compilation time: 100% of which was recompilation)
# j = 7
#   5.684645 seconds (269.52 M allocations: 4.891 GiB, 6.60% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 8
#   6.428481 seconds (319.36 M allocations: 5.788 GiB, 6.62% gc time, 0.70% compilation time: 100% of which was recompilation)
# j = 9
#   6.022495 seconds (296.24 M allocations: 5.378 GiB, 6.70% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 10
#   4.180075 seconds (207.09 M allocations: 3.773 GiB, 6.81% gc time, 1.17% compilation time: 100% of which was recompilation)
# j = 11
#   3.807164 seconds (187.25 M allocations: 3.411 GiB, 6.60% gc time, 1.34% compilation time: 100% of which was recompilation)
# j = 12
#   6.949537 seconds (334.18 M allocations: 6.032 GiB, 6.88% gc time, 0.70% compilation time: 100% of which was recompilation)
# j = 13
#   5.515457 seconds (259.41 M allocations: 4.782 GiB, 6.42% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 14
#   6.412446 seconds (305.33 M allocations: 5.522 GiB, 6.93% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 15
#   5.320248 seconds (239.03 M allocations: 4.388 GiB, 6.69% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 16
#   4.391566 seconds (212.91 M allocations: 3.883 GiB, 6.97% gc time, 1.21% compilation time: 100% of which was recompilation)
# j = 17
#   5.252105 seconds (248.24 M allocations: 4.552 GiB, 6.52% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 18
#   5.708738 seconds (280.01 M allocations: 5.102 GiB, 6.76% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 19
#   5.918666 seconds (275.50 M allocations: 5.013 GiB, 6.87% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 20
#   5.585319 seconds (266.51 M allocations: 4.844 GiB, 6.78% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 21
#   5.907746 seconds (272.00 M allocations: 4.974 GiB, 6.89% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 22
#   5.131995 seconds (245.52 M allocations: 4.500 GiB, 6.74% gc time, 1.04% compilation time: 100% of which was recompilation)
# j = 23
#   5.819639 seconds (284.40 M allocations: 5.180 GiB, 6.83% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 24
#   5.625892 seconds (271.06 M allocations: 4.916 GiB, 6.86% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 25
#   5.480150 seconds (262.60 M allocations: 4.816 GiB, 6.69% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 26
#   5.201241 seconds (255.67 M allocations: 4.671 GiB, 6.90% gc time, 1.19% compilation time: 100% of which was recompilation)
# j = 27
#   5.096559 seconds (264.04 M allocations: 4.813 GiB, 6.67% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 28
#   5.504649 seconds (285.63 M allocations: 5.173 GiB, 7.02% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 29
#   6.578109 seconds (315.28 M allocations: 5.723 GiB, 7.01% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 30
#   5.785918 seconds (248.82 M allocations: 4.571 GiB, 6.97% gc time, 1.42% compilation time: 100% of which was recompilation)
# j = 31
#   5.490146 seconds (259.81 M allocations: 4.754 GiB, 6.54% gc time, 1.16% compilation time: 100% of which was recompilation)
# j = 32
#   5.249338 seconds (263.08 M allocations: 4.815 GiB, 6.44% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 33
#   5.431989 seconds (265.67 M allocations: 4.839 GiB, 6.26% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 34
#   6.370106 seconds (299.22 M allocations: 5.416 GiB, 6.49% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 35
#   5.302187 seconds (271.55 M allocations: 4.950 GiB, 6.55% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 36
#   5.730756 seconds (296.06 M allocations: 5.391 GiB, 6.46% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 37
#   4.974852 seconds (266.70 M allocations: 4.847 GiB, 6.69% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 38
#   3.980755 seconds (208.86 M allocations: 3.801 GiB, 6.59% gc time, 1.06% compilation time: 100% of which was recompilation)
# j = 39
#   5.780425 seconds (280.49 M allocations: 5.127 GiB, 6.49% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 40
#   6.335277 seconds (304.39 M allocations: 5.507 GiB, 7.00% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 41
#   6.505278 seconds (314.22 M allocations: 5.681 GiB, 6.84% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 42
#   5.495829 seconds (277.67 M allocations: 5.047 GiB, 6.72% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 43
#   5.040497 seconds (274.69 M allocations: 4.991 GiB, 6.74% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 44
#   5.463925 seconds (289.49 M allocations: 5.226 GiB, 6.66% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 45
#   6.168044 seconds (340.79 M allocations: 6.129 GiB, 6.75% gc time, 0.73% compilation time: 100% of which was recompilation)
# j = 46
#   5.094780 seconds (288.89 M allocations: 5.225 GiB, 6.79% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 47
#   4.995325 seconds (272.39 M allocations: 4.971 GiB, 6.66% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 48
#   5.263900 seconds (273.35 M allocations: 4.987 GiB, 6.63% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 49
#   5.090233 seconds (260.45 M allocations: 4.747 GiB, 6.53% gc time, 1.00% compilation time: 100% of which was recompilation)
# j = 50
#   4.967488 seconds (275.71 M allocations: 5.025 GiB, 6.65% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 51
#   6.599785 seconds (369.72 M allocations: 6.640 GiB, 6.74% gc time, 0.62% compilation time: 100% of which was recompilation)
# j = 52
#   5.174896 seconds (286.85 M allocations: 5.219 GiB, 6.66% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 53
#   5.151967 seconds (282.87 M allocations: 5.131 GiB, 6.73% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 54
#   5.169099 seconds (290.37 M allocations: 5.250 GiB, 6.71% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 55
#   5.400103 seconds (296.40 M allocations: 5.354 GiB, 6.82% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 56
#   5.347296 seconds (278.66 M allocations: 5.071 GiB, 6.55% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 57
#   4.981019 seconds (270.91 M allocations: 4.914 GiB, 6.76% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 58
#   5.450909 seconds (297.74 M allocations: 5.410 GiB, 6.93% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 59
#   5.105551 seconds (273.58 M allocations: 4.974 GiB, 6.83% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 60
#   5.630450 seconds (300.45 M allocations: 5.435 GiB, 6.66% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 61
#   4.976130 seconds (254.60 M allocations: 4.662 GiB, 6.93% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 62
#   4.895406 seconds (255.50 M allocations: 4.668 GiB, 6.54% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 63
#   5.422135 seconds (280.29 M allocations: 5.089 GiB, 6.67% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 64
# ...
# j = 80
#   8.005097 seconds (308.91 M allocations: 5.596 GiB, 7.72% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 81
#   7.349218 seconds (286.14 M allocations: 5.190 GiB, 7.79% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 82
#   7.914495 seconds (277.67 M allocations: 5.074 GiB, 7.91% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 83
#   5.776981 seconds (223.25 M allocations: 4.083 GiB, 7.75% gc time, 1.15% compilation time: 100% of which was recompilation)
# j = 84
#   9.472615 seconds (277.35 M allocations: 5.059 GiB, 8.40% gc time, 0.67% compilation time: 100% of which was recompilation)
# j = 85
#   8.438843 seconds (302.18 M allocations: 5.445 GiB, 8.21% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 86
#   7.788604 seconds (265.99 M allocations: 4.852 GiB, 8.18% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 87
#   6.661571 seconds (218.48 M allocations: 3.981 GiB, 8.19% gc time, 1.24% compilation time: 100% of which was recompilation)
# j = 88
#   8.675792 seconds (281.05 M allocations: 5.126 GiB, 8.45% gc time, 0.75% compilation time: 100% of which was recompilation)
# j = 89
#   9.645039 seconds (288.91 M allocations: 5.287 GiB, 8.02% gc time, 0.68% compilation time: 100% of which was recompilation)
# j = 90
#   8.920636 seconds (272.75 M allocations: 4.961 GiB, 8.09% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 91
#   6.762563 seconds (246.31 M allocations: 4.521 GiB, 8.01% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 92
#   6.598092 seconds (253.73 M allocations: 4.640 GiB, 7.66% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 93
#   7.216686 seconds (272.23 M allocations: 4.952 GiB, 7.16% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 94
#   8.017513 seconds (306.77 M allocations: 5.555 GiB, 7.87% gc time, 0.81% compilation time: 100% of which was recompilation)
# j = 95
#   8.495996 seconds (278.52 M allocations: 5.095 GiB, 8.73% gc time, 0.72% compilation time: 100% of which was recompilation)
# j = 96
#   6.681084 seconds (245.88 M allocations: 4.514 GiB, 8.21% gc time, 0.99% compilation time: 100% of which was recompilation)
# j = 97
#   7.513015 seconds (269.74 M allocations: 4.904 GiB, 8.55% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 98
#   7.996691 seconds (277.33 M allocations: 5.041 GiB, 8.52% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 99
#   9.704950 seconds (335.02 M allocations: 6.072 GiB, 8.26% gc time, 0.66% compilation time: 100% of which was recompilation)
# j = 100
#   9.525897 seconds (326.97 M allocations: 5.927 GiB, 8.64% gc time, 0.63% compilation time: 100% of which was recompilation)
# Λ = 0.0005326622105352159
# j = 1
#   7.294891 seconds (268.34 M allocations: 4.874 GiB, 8.34% gc time, 1.59% compilation time: 100% of which was recompilation)
# j = 2
#   7.810324 seconds (281.69 M allocations: 5.103 GiB, 8.34% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 3
#   7.669110 seconds (281.38 M allocations: 5.125 GiB, 7.49% gc time, 1.68% compilation time: 100% of which was recompilation)
# j = 4
#   7.271330 seconds (267.77 M allocations: 4.891 GiB, 7.55% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 5
#   7.926638 seconds (292.50 M allocations: 5.311 GiB, 8.06% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 6
#   3.291073 seconds (124.51 M allocations: 2.258 GiB, 7.49% gc time, 2.47% compilation time: 100% of which was recompilation)
# j = 7
#   5.483731 seconds (204.89 M allocations: 3.720 GiB, 7.73% gc time, 1.20% compilation time: 100% of which was recompilation)
# j = 8
#   9.490455 seconds (307.77 M allocations: 5.588 GiB, 8.35% gc time, 0.70% compilation time: 100% of which was recompilation)
# j = 9
#   7.654883 seconds (287.77 M allocations: 5.227 GiB, 7.79% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 10
#   3.574184 seconds (128.62 M allocations: 2.332 GiB, 7.80% gc time, 1.75% compilation time: 100% of which was recompilation)
# j = 11
#   5.147242 seconds (187.25 M allocations: 3.411 GiB, 7.65% gc time, 1.40% compilation time: 100% of which was recompilation)
# j = 12
#   8.499550 seconds (320.16 M allocations: 5.794 GiB, 7.89% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 13
#   6.674737 seconds (253.17 M allocations: 4.666 GiB, 7.70% gc time, 0.98% compilation time: 100% of which was recompilation)
# j = 14
#   7.683191 seconds (295.42 M allocations: 5.348 GiB, 7.78% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 15
#   4.522689 seconds (172.89 M allocations: 3.146 GiB, 7.56% gc time, 1.43% compilation time: 100% of which was recompilation)
# j = 16
#   3.498677 seconds (132.62 M allocations: 2.405 GiB, 7.87% gc time, 1.80% compilation time: 100% of which was recompilation)
# j = 17
#   4.982848 seconds (186.31 M allocations: 3.396 GiB, 8.18% gc time, 1.23% compilation time: 100% of which was recompilation)
# j = 18
#   7.395137 seconds (272.15 M allocations: 4.961 GiB, 7.77% gc time, 1.32% compilation time: 100% of which was recompilation)
# j = 19
#   7.020413 seconds (267.40 M allocations: 4.868 GiB, 7.98% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 20
#   5.370538 seconds (197.40 M allocations: 3.582 GiB, 7.88% gc time, 1.15% compilation time: 100% of which was recompilation)
# j = 21
#   6.867946 seconds (265.22 M allocations: 4.850 GiB, 7.79% gc time, 1.11% compilation time: 100% of which was recompilation)
# j = 22
#   4.608573 seconds (176.59 M allocations: 3.214 GiB, 7.86% gc time, 1.41% compilation time: 100% of which was recompilation)
# j = 23
#   7.032910 seconds (272.79 M allocations: 4.970 GiB, 8.00% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 24
#   5.008636 seconds (190.30 M allocations: 3.451 GiB, 7.86% gc time, 1.25% compilation time: 100% of which was recompilation)
# j = 25
#   6.724689 seconds (256.34 M allocations: 4.700 GiB, 7.58% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 26
#   5.386914 seconds (202.99 M allocations: 3.698 GiB, 7.72% gc time, 1.17% compilation time: 100% of which was recompilation)
# j = 27
#   6.934748 seconds (246.38 M allocations: 4.488 GiB, 7.88% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 28
#   7.374152 seconds (275.05 M allocations: 4.989 GiB, 7.84% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 29
#   8.587749 seconds (304.40 M allocations: 5.534 GiB, 7.98% gc time, 0.74% compilation time: 100% of which was recompilation)
# j = 30
#   6.363053 seconds (236.64 M allocations: 4.342 GiB, 8.08% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 31
#   6.930660 seconds (249.47 M allocations: 4.564 GiB, 7.72% gc time, 1.04% compilation time: 100% of which was recompilation)
# j = 32
#   6.339371 seconds (256.71 M allocations: 4.697 GiB, 7.68% gc time, 1.06% compilation time: 100% of which was recompilation)
# j = 33
#   4.845678 seconds (224.14 M allocations: 4.080 GiB, 7.78% gc time, 1.08% compilation time: 100% of which was recompilation)
# j = 34
#   6.370898 seconds (288.53 M allocations: 5.230 GiB, 8.24% gc time, 1.09% compilation time: 100% of which was recompilation)
# j = 35
#   5.951515 seconds (263.97 M allocations: 4.812 GiB, 7.77% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 36
#   5.697353 seconds (286.37 M allocations: 5.222 GiB, 7.54% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 37
#   4.587615 seconds (207.97 M allocations: 3.778 GiB, 7.89% gc time, 1.02% compilation time: 100% of which was recompilation)
# j = 38
#   2.611725 seconds (128.52 M allocations: 2.331 GiB, 7.26% gc time, 2.22% compilation time: 100% of which was recompilation)
# j = 39
#   5.002211 seconds (273.14 M allocations: 4.994 GiB, 7.41% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 40
#   5.613597 seconds (292.98 M allocations: 5.311 GiB, 7.86% gc time, 0.73% compilation time: 100% of which was recompilation)
# j = 41
#   5.793533 seconds (304.11 M allocations: 5.505 GiB, 7.41% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 42
#   5.256475 seconds (268.55 M allocations: 4.886 GiB, 7.52% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 43
#   5.367603 seconds (265.76 M allocations: 4.833 GiB, 7.66% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 44
#   5.705677 seconds (274.33 M allocations: 4.960 GiB, 7.48% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 45
#   7.629994 seconds (327.17 M allocations: 5.898 GiB, 7.33% gc time, 0.65% compilation time: 100% of which was recompilation)
# j = 46
#   5.272948 seconds (273.69 M allocations: 4.959 GiB, 7.33% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 47
#   4.907596 seconds (263.58 M allocations: 4.815 GiB, 7.52% gc time, 0.96% compilation time: 100% of which was recompilation)
# j = 48
#   5.617692 seconds (265.43 M allocations: 4.845 GiB, 7.44% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 49
#   4.403440 seconds (207.97 M allocations: 3.787 GiB, 7.72% gc time, 1.15% compilation time: 100% of which was recompilation)
# j = 50
#   5.457424 seconds (268.50 M allocations: 4.894 GiB, 7.36% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 51
#   8.061008 seconds (348.16 M allocations: 6.274 GiB, 7.50% gc time, 0.67% compilation time: 100% of which was recompilation)
# j = 52
#   7.011948 seconds (278.20 M allocations: 5.065 GiB, 7.74% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 53
#   5.703753 seconds (270.48 M allocations: 4.908 GiB, 7.89% gc time, 0.94% compilation time: 100% of which was recompilation)
# j = 54
#   5.831849 seconds (279.88 M allocations: 5.067 GiB, 7.93% gc time, 0.83% compilation time: 100% of which was recompilation)
# j = 55
#   5.858416 seconds (286.41 M allocations: 5.179 GiB, 7.58% gc time, 0.86% compilation time: 100% of which was recompilation)
# j = 56
#   5.165476 seconds (265.56 M allocations: 4.837 GiB, 7.75% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 57
#   3.911503 seconds (215.26 M allocations: 3.903 GiB, 7.59% gc time, 1.07% compilation time: 100% of which was recompilation)
# j = 58
#   5.530343 seconds (288.81 M allocations: 5.252 GiB, 7.45% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 59
#   5.553889 seconds (265.71 M allocations: 4.832 GiB, 7.69% gc time, 0.91% compilation time: 100% of which was recompilation)
# j = 60
#   5.744524 seconds (289.96 M allocations: 5.253 GiB, 8.12% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 61
#   4.364491 seconds (231.81 M allocations: 4.238 GiB, 7.48% gc time, 0.99% compilation time: 100% of which was recompilation)
# j = 62
#   3.497414 seconds (185.53 M allocations: 3.375 GiB, 7.72% gc time, 1.24% compilation time: 100% of which was recompilation)
# j = 63
#   5.099712 seconds (271.59 M allocations: 4.934 GiB, 7.65% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 64
#   4.652696 seconds (255.16 M allocations: 4.663 GiB, 7.53% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 65
#   3.404779 seconds (182.57 M allocations: 3.319 GiB, 7.79% gc time, 1.30% compilation time: 100% of which was recompilation)
# j = 66
#   4.776567 seconds (259.62 M allocations: 4.734 GiB, 7.57% gc time, 0.92% compilation time: 100% of which was recompilation)
# j = 67
#   3.619332 seconds (193.66 M allocations: 3.532 GiB, 7.58% gc time, 1.15% compilation time: 100% of which was recompilation)
# j = 68
#   4.567655 seconds (245.48 M allocations: 4.483 GiB, 7.56% gc time, 0.97% compilation time: 100% of which was recompilation)
# j = 69
#   4.296476 seconds (227.94 M allocations: 4.132 GiB, 7.49% gc time, 1.02% compilation time: 100% of which was recompilation)
# j = 70
#   4.016012 seconds (217.47 M allocations: 3.956 GiB, 7.76% gc time, 1.03% compilation time: 100% of which was recompilation)
# j = 71
#   5.175530 seconds (285.20 M allocations: 5.194 GiB, 7.74% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 72
#   4.848512 seconds (257.99 M allocations: 4.726 GiB, 7.60% gc time, 0.89% compilation time: 100% of which was recompilation)
# j = 73
#   5.552843 seconds (295.42 M allocations: 5.348 GiB, 7.65% gc time, 0.77% compilation time: 100% of which was recompilation)
# j = 74
#   5.419385 seconds (272.75 M allocations: 4.978 GiB, 7.62% gc time, 0.93% compilation time: 100% of which was recompilation)
# j = 75
#   5.078164 seconds (269.04 M allocations: 4.928 GiB, 7.68% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 76
#   5.323974 seconds (284.53 M allocations: 5.167 GiB, 7.55% gc time, 0.88% compilation time: 100% of which was recompilation)
# j = 77
#   6.005583 seconds (272.74 M allocations: 4.953 GiB, 7.72% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 78
#   4.772070 seconds (197.56 M allocations: 3.594 GiB, 7.97% gc time, 1.33% compilation time: 100% of which was recompilation)
# j = 79
#   4.824275 seconds (262.00 M allocations: 4.773 GiB, 7.20% gc time, 1.09% compilation time: 100% of which was recompilation)
# j = 80
#   5.439518 seconds (298.78 M allocations: 5.419 GiB, 7.43% gc time, 0.76% compilation time: 100% of which was recompilation)
# j = 81
#   5.111024 seconds (276.74 M allocations: 5.025 GiB, 7.25% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 82
#   5.221357 seconds (271.07 M allocations: 4.952 GiB, 7.42% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 83
#   3.172493 seconds (162.54 M allocations: 2.954 GiB, 7.39% gc time, 1.38% compilation time: 100% of which was recompilation)
# j = 84
#   5.750852 seconds (269.46 M allocations: 4.918 GiB, 7.00% gc time, 1.01% compilation time: 100% of which was recompilation)
# j = 85
#   6.087851 seconds (291.23 M allocations: 5.255 GiB, 7.52% gc time, 0.84% compilation time: 100% of which was recompilation)
# j = 86
#   5.267828 seconds (261.65 M allocations: 4.775 GiB, 7.55% gc time, 0.95% compilation time: 100% of which was recompilation)
# j = 87
#   2.746453 seconds (152.45 M allocations: 2.766 GiB, 7.68% gc time, 1.53% compilation time: 100% of which was recompilation)
# j = 88
#   5.040139 seconds (271.75 M allocations: 4.962 GiB, 7.58% gc time, 0.82% compilation time: 100% of which was recompilation)
# j = 89
#   5.819409 seconds (281.26 M allocations: 5.148 GiB, 7.24% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 90
#   4.916686 seconds (264.66 M allocations: 4.815 GiB, 7.53% gc time, 0.85% compilation time: 100% of which was recompilation)
# j = 91
#   3.893404 seconds (213.31 M allocations: 3.907 GiB, 7.30% gc time, 1.14% compilation time: 100% of which was recompilation)
# j = 92
#   4.059559 seconds (222.25 M allocations: 4.059 GiB, 7.44% gc time, 1.04% compilation time: 100% of which was recompilation)
# j = 93
#   4.812790 seconds (264.03 M allocations: 4.805 GiB, 7.69% gc time, 1.10% compilation time: 100% of which was recompilation)
# j = 94
#   5.501838 seconds (298.26 M allocations: 5.403 GiB, 7.50% gc time, 0.78% compilation time: 100% of which was recompilation)
# j = 95
#   4.946454 seconds (271.20 M allocations: 4.962 GiB, 7.58% gc time, 0.87% compilation time: 100% of which was recompilation)
# j = 96
#   4.002917 seconds (190.21 M allocations: 3.476 GiB, 7.79% gc time, 1.05% compilation time: 100% of which was recompilation)
# j = 97
#   4.872375 seconds (254.06 M allocations: 4.620 GiB, 7.65% gc time, 1.06% compilation time: 100% of which was recompilation)
# j = 98
#   5.381959 seconds (271.76 M allocations: 4.946 GiB, 7.76% gc time, 0.80% compilation time: 100% of which was recompilation)
# j = 99
#   6.641726 seconds (323.55 M allocations: 5.874 GiB, 7.45% gc time, 1.15% compilation time: 100% of which was recompilation)
# j = 100
#   5.800905 seconds (316.21 M allocations: 5.740 GiB, 7.35% gc time, 0.80% compilation time: 100% of which was recompilation)

# %% [markdown]
# ## Observation procedure M-R

# %% [markdown]
# This section is dedicated to the creation of datasets including only M-R values. One can choose the number N of observation points on the M-R curve (e.g. we worked with N=15,20,30), and the number ns of Gaussian noise injections (e.g. we worked with ns=100,200,300).

# %%
function DataGenerator(R_rand::AbstractVector{T}, M_rand::AbstractVector{T},
        DATA_matrix, iMax, σM, σR, TOT) where T
    #interpolate R-M curve
    M_array = Interpolations.deduplicate_knots!(DATA_matrix[:,2];move_knots = true);
    RMcurve = linear_interpolation(M_array[1:iMax],DATA_matrix[1:iMax,3])
    
    M_rand = rand(Uniform(M_array[1],M_array[iMax]),TOT)
    R_rand = RMcurve.(M_rand)
    #Shifting the data
    M_rand = rand.(Normal.(M_rand,σM))./Mnorm
    R_rand = rand.(Normal.(R_rand,σR))./Rnorm
    return R_rand, M_rand
end;

#functions to search for file in folder
searchdir(path,key) = filter(x->occursin(key,x), readdir(path));

# %%
Λtemp= [-194, -150, -120, -95, -50, 0, 50, 95, 120, 194]
const σM = 0.1
const σR = 0.5
const Mnorm = 3.
const Rnorm = 20.
ns = 300 #100 #200 #300
TOT = 30 #Choose number of observation points 15, 20, 30

for i = 1:length(Λtemp)
    @show i
    
    tempΛ = Λtemp[i]
    listFile = searchdir("TOVs","_$tempΛ"*"_")
    
    for j = 1:length(listFile)
        #@show j
        #obtain remaining features
        eos = split(split(listFile[j], ".")[1],"_")[2]
        z = parse(Int,split(split(listFile[j], ".")[1],"_")[4])
        #extract TOV
        TOV_matrix = readdlm("TOVs/"*listFile[j], Float64)
        
        #extract random observation set ns times for each eos
        for h = 1:ns
            R_rand = zeros(0)
            M_rand = zeros(0)
            _, iMax = findmax(TOV_matrix[:,2])
            R_rand, M_rand = DataGenerator(R_rand, M_rand, TOV_matrix, iMax, σM, σR, TOT)
        
            dumping = open("dataset_30points_larger300.csv", "a");
            writedlm( dumping,  [eos tempΛ adjoint(matrix_ρ[z,:]) adjoint(matrix_cs[z,:]) adjoint(M_rand) adjoint(R_rand)], ' ')
            close(dumping)
        end
    end
end

# %% [markdown]
# ## Observation procedure M-R-k2

# %% [markdown]
# This section is dedicated to the creation of datasets including M-R-k2 triplets. One can choose the number N of observation points on the M-R curve (e.g. we worked with N=15,20,30), and the number ns of Gaussian noise injections (e.g. we worked with ns=100,200,300).
#
# Note: remember to search in correct folder (training and validation datasets in "TOVs", testing in "TOVsTest")

# %%
function DataGenerator(R_rand::AbstractVector{T}, M_rand::AbstractVector{T},
        k2_rand::AbstractVector{T}, DATA_matrix, iMax, TOT) where T
    #interpolate R-M curve
    M_array = Interpolations.deduplicate_knots!(DATA_matrix[:,2];move_knots = true);
    k2array = (3.0 / 2.0) .* DATA_matrix[:,4] .* DATA_matrix[:,2] .^5  ./DATA_matrix[:,3].^5/ KK^5
    RMcurve = linear_interpolation(M_array[1:iMax],DATA_matrix[1:iMax,3])
    k2Mcurve = linear_interpolation(M_array[1:iMax],k2array[1:iMax])
    
    M_rand = rand(Uniform(M_array[1],M_array[iMax]),TOT)
    R_rand = RMcurve.(M_rand)
    k2_rand = k2Mcurve.(M_rand)
    #Shifting the data
    M_rand = rand.(Normal.(M_rand,σM))./Mnorm
    R_rand = rand.(Normal.(R_rand,σR))./Rnorm
    k2_rand = rand.(Normal.(k2_rand,σk2))#renormalization done after
    return R_rand, M_rand, k2_rand
end;

#functions to search for file in folder
searchdir(path,key) = filter(x->occursin(key,x), readdir(path));

# %%
Λtemp= [-194, -150, -120, -95, -50, 0, 50, 95, 120, 194]
const σM = 0.1
const σR = 0.5
const σk2 = 0.05
const Mnorm = 3.
const Rnorm = 20.
ns = 100 #100 #200 #300
TOT = 30 #Choose number of observation points 15, 20, 30

for i = 1:length(Λtemp)
    @show i
    
    tempΛ = Λtemp[i]
    #listFile = searchdir("TOVs","_$tempΛ"*"_")
    listFile = searchdir("TOVsTest","_$tempΛ"*"_")
    
    for j = 1:length(listFile)
        #@show j
        #obtain remaining features
        eos = split(split(listFile[j], ".")[1],"_")[2]
        z = parse(Int,split(split(listFile[j], ".")[1],"_")[4])
        #extract TOV
        #TOV_matrix = readdlm("TOVs/"*listFile[j], Float64)
        TOV_matrix = readdlm("TOVsTest/"*listFile[j], Float64)
        
        #extract random observation set ns times for each eos
        for h = 1:ns
            R_rand = zeros(0)
            M_rand = zeros(0)
            k2_rand = zeros(0)
            _, iMax = findmax(TOV_matrix[:,2])
            R_rand, M_rand, k2_rand = DataGenerator(R_rand, M_rand, k2_rand, TOV_matrix, iMax, TOT)
        
            dumping = open("datasetk2_30points_Test_100.csv", "a");
            writedlm( dumping,  [eos tempΛ adjoint(matrix_ρ[z,:]) adjoint(matrix_cs[z,:]) adjoint(M_rand) adjoint(R_rand) adjoint(k2_rand)], ' ')
            close(dumping)
        end
    end
end
# Out:
# i = 1
# i = 2
# i = 3
# i = 4
# i = 5
# i = 6
# i = 7
# i = 8
# i = 9
# i = 10

# %% [markdown]
# ## Analysis of predicted EOSs

# %% [markdown]
# Let us now analyse the predicted EOS from our deep neural networks (done in a separate python notebook). Given and EOS, we solve the TOV and tidal deformability equations and we plot the results comparing them with the expected ones.

# %% [markdown]
# ### Integrating the equations

# %% [markdown]
# We integrate here the TOV and tidal deformability equations.
#
# Note: Load the appropriate functions.

# %%
const ρt = 2.0 * n0 * m * ρu #mass density when transition happens
const ρfin = 12.0 * n0 * m * ρu
const pc = 200.0^4 * Kp * Pu #threshold corresponds to qcd scale
#define initial values for solving integration as global
const r0 = 10^-5
const a0 = 1.0
const f0 = 1.0
const h0 = 1.0
const H0 = a0 * r0^2
const β0 = 2. * a0 * r0
const rspan = (r0, 200);

# %%
ϵ_fluid = zeros(0)
ϵ_prime(x::Any) = zeros(0)
DATA_matrix = Matrix{Float64}(undef,0,4)
Λ=0.

#choose which EOS to plot (EOS are saved in python notebook)
j = 100
N = 30
n = 10
EOS = readdlm("EOSj$j"*"N$N"*"n$n.txt", Float64)

coeff = 0.0052048215522052
matrix_ρ = EOS[:,3:9] .* coeff
matrix_cs = EOS[:,10:16]

for q = 2:11
    @show(q)

    z = q #It goes from 1 to 11 (1 is real data, other 10 predicted)
    temp = EOS[z,2] * 388. - 194.
    Λ = sign(temp)*(EOS[z,2] * 388. - 194.)^4 * Kp * Pu
    @show(Λ)

    if EOS[z,1] == 0
        baseline_eos = ap4
    else
        baseline_eos = sly
    end
    
    
    eos_matrix = Matrix{Float64}(undef,0,3) #define matrix to store complete eos
    eos_matrix = build(eos_matrix, baseline_eos, matrix_ρ, matrix_cs, z)

    #ϵ[p] before transition
    ϵ_fluid = linear_interpolation(eos_matrix[:,1],eos_matrix[:,2])
    #define interpolated dϵ[p]/dp
    ϵ_prime(x) = only(Interpolations.gradient(ϵ_fluid, x) );
        
    #INTEGRATOR
    P0 = 2.5 * 10^-5  #this will vary at each step of loop
    Pf = 0. #define it
    #Find what Pf is
    if Λ > 0. && eos_matrix[end,1] > pc
        Pf = eos_matrix[end,1] - Λ
    else
        Pf = eos_matrix[end,1]
    end

    #create empty matrix to store data in loop
    DATA_matrix = Matrix{Float64}(undef,0,4) 

    @time DATA_matrix = cycleTOV(DATA_matrix, P0, Pf)
    
    dumping = open("TOV_j$j"*"_N$N"*"_ns$n"*"_$z.csv", "a")
    writedlm(dumping, DATA_matrix, ' ')
    close(dumping)
    
end;

# %% [markdown]
# ### Plots

# %% [markdown]
# #### Plotting curves

# %%
const Mnorm = 3.
const Rnorm = 20.
const σM = 0.1
const σR = 0.5
const σk2 = 0.05
k2max, k2min = 1.66007354312931, -1.57981785098554
#To compare with real curves, it's important to find the corresponding saved file in TOVsTest
#At the moment this is done manually, for j=100 and j=1210 this is:
realMR = readdlm("TOVsTest/TOV_ap4_-194_70.csv", Float64); #j=100
#realMR = readdlm("TOVsTest/TOV_sly_120_85.csv", Float64); #j=1210

# %%
xvalue = [10,11,12,13]
xstring = [L"10",L"11",L"12",L"13"]
yvalue = [0.5,1.0,1.5,2.0]
ystring = [L"0.5",L"1.0", L"1.5", L"2.0"]

#REMEMBER to change labels accordingly
j = 100
N = 30
n = 10

EOS_data = readdlm("TOV_j$j"*"_N$N"*"_ns$n"*"_2.csv", Float64)

plotFig = plot(EOS_data[:,3],EOS_data[:,2],color=palette(:tab10)[1],label="",
    xlabel=L"R\ [\textrm{km}]",ylabel=L"M\ [M_\odot]",
    yticks=(yvalue, ystring), 
    xticks=(xvalue, xstring),
    xtickfont=font(12), ytickfont=font(12),framestyle=:box, dpi=300,
    legendfontsize=10,xguidefontsize=14,yguidefontsize=14,legend=:bottomleft)
for i=3:11
    EOS_data = readdlm("TOV_j$j"*"_N$N"*"_ns$n"*"_$i.csv", Float64)
    plot!(EOS_data[:,3],EOS_data[:,2],color=palette(:tab10)[i-1],label="")
end

plot!(realMR[:,3],realMR[:,2],color="black", linewidth=1.5,
    label=L"\textrm{real: AP4},\Lambda=-(194\ \textrm{MeV})^4", labelfont=font(12))

shift_data = readdlm("EOSj$j"*"N$N"*"n$n"*"real.txt", Float64)
scatter!(shift_data[31:60].* Rnorm,shift_data[1:30].*Mnorm, yerr = σM, xerr = σR,label="",
    color="grey",alpha=0.6)
#savefig(plotFig,"MR_N194.png");

# %%
xvalue = [0.5,1.0,1.5,2.0]
xstring = [L"0.5",L"1.0", L"1.5", L"2.0"]
yvalue = [0.05,0.07,0.09,0.11]
ystring = [L"0.05",L"0.07", L"0.09", L"0.11"]

j = 100
N = 30
n = 10
EOS_data = readdlm("TOV_j$j"*"_N$N"*"_ns$n"*"_2.csv", Float64)

plotFig=plot(EOS_data[:,2],
    (3.0 / 2.0) .* EOS_data[:,4] .* EOS_data[:,2] .^5  ./EOS_data[:,3].^5/ KK^5,
    color=palette(:tab10)[1],label="",
    xlabel=L"M\ [M_\odot]",ylabel=L"k_2",
    yticks=(yvalue, ystring), 
    xticks=(xvalue, xstring),
    xtickfont=font(12), ytickfont=font(12),framestyle=:box, dpi=300,
    legendfontsize=10,xguidefontsize=14,yguidefontsize=14,legend=:topright)

for i=3:11
    EOS_data = readdlm("TOV_j$j"*"_N$N"*"_ns$n"*"_$i.csv", Float64)
    plot!(EOS_data[:,2],
    (3.0 / 2.0) .* EOS_data[:,4] .* EOS_data[:,2] .^5  ./EOS_data[:,3].^5/ KK^5,
    color=palette(:tab10)[i-1],label="")

end

plot!(realMR[:,2],
    (3.0 / 2.0) .* realMR[:,4] .* realMR[:,2] .^5  ./realMR[:,3].^5/ KK^5,
    color="black",
    linewidth=1.5,label=L"\textrm{real: AP4},\Lambda=-(194\ \textrm{MeV})^4", 
    labelfont=font(12))

#savefig(plotFig,"k2M_N194.png");

# %%
xvalue = [0.5,1.0,1.5,2.0]
xstring = [L"0.5",L"1.0", L"1.5", L"2.0"]
yvalue = [-0.3,-0.2,-0.1,0,0.1]
ystring = [L"-0.3",L"-0.2", L"-0.1",L"0",L"0.1"]

k2Mcurve0 = linear_interpolation(realMR[:,2],(3.0 / 2.0) .* 
    realMR[:,4] .* realMR[:,2] .^5  ./realMR[:,3].^5/ KK^5)

j = 100
N = 30
n = 10
EOS_data = readdlm("TOV_j$j"*"_N$N"*"_ns$n"*"_2.csv", Float64)
_, iMax = findmax(EOS_data[:,2])
k2Mcurve = linear_interpolation(EOS_data[1:iMax,2],(3.0 / 2.0) .* 
        EOS_data[1:iMax,4] .* EOS_data[1:iMax,2].^5 ./EOS_data[1:iMax,3].^5/ KK^5)
Diff = (k2Mcurve(EOS_data[1:iMax,2]) .- 
    k2Mcurve0(EOS_data[1:iMax,2]))./k2Mcurve0(EOS_data[1:iMax,2])

plotFig=plot(EOS_data[1:iMax,2], Diff,
    color=palette(:tab10)[1],label="",
    xlabel=L"M\ [M_\odot]",ylabel=L"(k_2-k_{2,\textrm{real}})/k_{2,\textrm{real}}",
    yticks=(yvalue, ystring), 
    xticks=(xvalue, xstring),
    xtickfont=font(12), ytickfont=font(12),framestyle=:box, dpi=300,
    legendfontsize=10,xguidefontsize=14,yguidefontsize=14,legend=:topright,
    title=L"\textrm{AP4},\Lambda=-(194\ \textrm{MeV})^4")
for i=3:11
    EOS_data = readdlm("TOV_j$j"*"_N$N"*"_ns$n"*"_$i.csv", Float64)
    _, iMax = findmax(EOS_data[:,2])
    k = 1
    if realMR[1,2] > EOS_data[1,2]
        k = findpos(EOS_data,realMR[1,2],2)+1
    end
    k2Mcurve = linear_interpolation(EOS_data[k:iMax,2],(3.0 / 2.0) .* 
        EOS_data[k:iMax,4] .* EOS_data[k:iMax,2].^5 ./EOS_data[k:iMax,3].^5/ KK^5)
    Diff = (k2Mcurve(EOS_data[k:iMax,2]) .- 
        k2Mcurve0(EOS_data[k:iMax,2]))./k2Mcurve0(EOS_data[k:iMax,2]);
    plot!(EOS_data[k:iMax,2],Diff, color=palette(:tab10)[i-1],label="")
end

plotFig
#savefig(plotFig,"k2Mdiff_N194.png");

# %% [markdown]
# #### Reconstruct EOS

# %%
ϵ_fluid = zeros(0)
ϵ_prime(x::Any) = zeros(0)

#choose which EOS to plot (EOS are saved in python notebook)
j = 1210
N = 30
n = 10
EOS = readdlm("EOSj$j"*"N$N"*"n$n.txt", Float64)

Λ=0. #define Λ outside of loop
coeff = 0.0052048215522052
matrix_ρ = EOS[:,3:9] .* coeff
matrix_cs = EOS[:,10:16]

for q = 1:11
    z = q

    temp = EOS[z,2] * 388. - 194.
    Λ = sign(temp)*(EOS[z,2] * 388. - 194.)^4 * Kp * Pu
    
    if EOS[z,1] == 0
        baseline_eos = ap4
    else
        baseline_eos = sly
    end
 
    eos_matrix = Matrix{Float64}(undef,0,3) #define matrix to store complete eos
    eos_matrix = build(eos_matrix, baseline_eos, matrix_ρ, matrix_cs, z)
        
    #ϵ[p] before transition
    ϵ_fluid = linear_interpolation(eos_matrix[:,1], eos_matrix[:,2])
    
    if Λ > 0 && eos_matrix[end,1] > pc
        Pf = eos_matrix[end,1] - Λ
    else
        Pf = eos_matrix[end,1]
    end

    k = findpos(eos_matrix,Pf,1)
    tosave = [eos_matrix[1:k-1,1] eos_interp.(eos_matrix[1:k-1,1])] 
    writedlm("EOS_j$j"*"N$N"*"n$n"*"z$z.csv",  tosave, ' ')
end;

# %%
j = 100
N = 30
n = 10
EOS_plot = readdlm("EOS_j$j"*"N$N"*"n$n"*"z1.csv", Float64)
plotFig=plot(EOS_plot[:,1]./Pu,EOS_plot[:,2]./ρu, yaxis=:log10, xaxis=:log10, 
    legend=:bottomright,
    ylimits=(3*10.0^14,6.0*10.0^15),xlimits=(9.0*10.0^34,1.1*10.0^36),#j=100
    #ylimits=(9*10.0^14,7.0*10.0^15),xlimits=(3*10.0^35,1.5*10.0^36),#j=1210
    color="black", linewidth=1.5,label="",
    labelfont=font(12),xlabel="",
    ylabel="",
    yformatter=_->"", 
    xformatter=_->"",
    xtickfont=font(12), ytickfont=font(12),framestyle=:box, dpi=300)
for i = 2:11
    EOS_plot = readdlm("EOS_j$j"*"N$N"*"n$n"*"z$i.csv", Float64)
    plot!(EOS_plot[:,1]./Pu,EOS_plot[:,2]./ρu, yaxis=:log10, xaxis=:log10,
        color=palette(:tab10)[i-1],label="")
end
plotFig
#savefig(plotFig,"inset__120.png");
savefig(plotFig,"inset__N194.png");

# %%
#img = load("inset_120.png")
img = load("inset_N194.png")

xvalue = [10.0^10,10.0^20, 10.0^30]
xstring = [L"10^{10}",L"10^{20}",L"10^{30}"]
yvalue = [10.0^5,10.0^10,10.0^15]
ystring = [L"10^{5}",L"10^{10}", L"10^{15}"]

j = 100
N = 30
n = 10
EOS_plot = readdlm("EOS_j$j"*"N$N"*"n$n"*"z1.csv", Float64)
plotFig=plot(EOS_plot[:,1]./Pu,EOS_plot[:,2]./ρu, yaxis=:log10, xaxis=:log10, 
    legend=:bottomright,
    #ylimits=(10^-5,10^-2),xlimits=(10^-10,0),
    color="black", linewidth=1.5,label=L"\textrm{real: SLy},\Lambda=(120\ \textrm{MeV})^4",
    labelfont=font(12),xlabel=L"p[\textrm{g\ cm^{-1} s^{-2}}]",
    ylabel=L"\epsilon[\textrm{g\ cm^{-3}}]",
    yticks=(yvalue, ystring), 
    xticks=(xvalue, xstring),
    xtickfont=font(12), ytickfont=font(12),framestyle=:box, dpi=300,
    xguidefontsize=14,yguidefontsize=14,legendfontsize=10)

for i=2:11
    EOS_plot = readdlm("EOS_j$j"*"N$N"*"n$n"*"z$i.csv", Float64)
    plot!(EOS_plot[:,1]./Pu,EOS_plot[:,2]./ρu, yaxis=:log10, xaxis=:log10,
        color=palette(:tab10)[i-1],label="")
end


plot!([0,1],[0,1],reverse(img, dims = 1), yflip = false, aspect_ratio = :none,
    inset = (1, bbox(0.02, 0.02,0.58, 0.49, :top, :left)),ticks = nothing,
    subplot = 2,
    #bg_inside = nothing
)
plotFig
#savefig(plotFig,"EOS_120.png");

# %%
EOS_data = readdlm("EOSj0N30n100.txt", Float64)
N = 100
δρ = (minimum(EOS_data[:,9])-maximum(EOS_data[:,3]))/N
for l = 2:101 #cycle on interpolated curve 
    curveInt = linear_interpolation(EOS_data[l,3:9],EOS_data[l,10:end])
    ρ0 = maximum(EOS_data[:,3])
    data_matrix = Matrix{Float64}(undef,0,1)
    for i = 1:N+1 #cycle on ρ
        speed = curveInt(ρ0)
        data_matrix = vcat(data_matrix, [speed])
        ρ0 += δρ
    end
    dumping = open("IntCurve100.csv", "a")
    writedlm(dumping, transpose(data_matrix), ' ')
    close(dumping)
end

# %%
#TO FIND MAX AND MIN FOR EACH ρ
IntCurve = readdlm("IntCurve100.csv", Float64)
min_values = zeros(0)
max_values = zeros(0)
ρ_values = zeros(0)
N=100
δρ = (minimum(EOS_data[:,9])-maximum(EOS_data[:,3]))/N
ρ0 = maximum(EOS_data[:,3])

for i=1:N+1
    speedmin = minimum(IntCurve[:,i])
    speedmax = maximum(IntCurve[:,i])
        
    ρ_values = vcat(ρ_values, [ρ0])
    min_values = vcat(min_values, [speedmin])
    max_values = vcat(max_values, [speedmax])
    ρ0 += δρ
end

# %%
#TO FIND MEAN AND σ FOR EACH ρ
IntCurve = readdlm("IntCurve100.csv", Float64)
mean_values = zeros(0)
sigma_values = zeros(0)
ρ_values = zeros(0)
N=100
δρ = (minimum(EOS_data[:,9])-maximum(EOS_data[:,3]))/N
ρ0 = maximum(EOS_data[:,3])

for i=1:N+1
    mean_val = mean(IntCurve[:,i])
    sigma_val = std(IntCurve[:,i])
        
    ρ_values = vcat(ρ_values, [ρ0])
    mean_values = vcat(mean_values, [mean_val])
    sigma_values = vcat(sigma_values, [sigma_val])
    
    ρ0 += δρ
end

# %%
xvalue = [0,0.2,0.4,0.6,0.8,1]
xstring = [L"0",L"0.2",L"0.4",L"0.6",L"0.8",L"1"]
yvalue = [0,0.2,0.4,0.6,0.8,1]
ystring = [L"0",L"0.2",L"0.4",L"0.6",L"0.8",L"1"]
plotFig=plot(EOS_data[1,3:9],EOS_data[1,10:end], color=:black,linewidth=1.5,framestyle=:box, 
    dpi=300,
    label=L"\textrm{real}",labelfont=font(16),xlabel=L"\rho/\rho_f",ylabel=L"c_s",
    yticks=(yvalue, ystring), 
    xticks=(xvalue, xstring),
    ylimits=(0,1),xlimits=(0,1),
    xtickfont=font(12), ytickfont=font(12),
    xguidefontsize=16,yguidefontsize=16,legendfontsize=11)
for i =2:101
    plot!(EOS_data[i,3:9],EOS_data[i,10:end], color=palette(:tab10)[1],label = "",
    alpha=0.2)
end
#plot!(ρ_values,min_values,color="grey",label="",style=:dash)
#plot!(ρ_values,max_values,color="grey",label="",style=:dash)
#plot!(ρ_values,mean_values,color=palette(:tab10)[1],label="")
plot!(ρ_values,mean_values.+2.0 .*sigma_values,color=palette(:tab10)[1],label="")
#plot!(ρ_values,mean_values.-2.0 .*sigma_values,color="grey",label="",style=:dash)
plot!(ρ_values, mean_values.-2.0 .*sigma_values, 
    fillrange = mean_values.+2.0 .*sigma_values, 
    fillalpha = 0.35, color=palette(:tab10)[1], label="")

# %%
data_test = readdlm("data_test.txt", Float64)
data_hat = readdlm("data_hat.txt", Float64);

# %%
line = [0.39,0.8]
xvalue = [0.4,0.5,0.6,0.7,0.8]
xstring = [L"0.4",L"0.5",L"0.6",L"0.7",L"0.8"]
yvalue = [0.4,0.5,0.6,0.7,0.8]
ystring = [L"0.4",L"0.5",L"0.6",L"0.7",L"0.8"]
plotFig=scatter(data_test[:,1],data_hat[:,1],yerr = 3.0.*data_hat[:,2], label="",
    ylimits=(0.39,0.8),xlimits=(0.39,0.8),color=:black,markersize=3,framestyle=:box, 
    dpi=300,xlabel=L"\langle c_s \rangle_\textrm{real}",
    ylabel=L"\langle c_s \rangle_\textrm{pred}",
    yticks=(yvalue, ystring), 
    xticks=(xvalue, xstring),
    xtickfont=font(12), ytickfont=font(12),
    xguidefontsize=16,yguidefontsize=16,legendfontsize=11)
plot!(line,line,color=:grey,label="",linestyle=:dash)
#savefig(plotFig,"c_sMean.png");
